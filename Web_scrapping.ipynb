# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
webpage=requests.get("https://www.eventbrite.com/d/united-states/all-events/?page=4").text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    United States All Events | Eventbrite
#         - Page 4
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="en" http-equiv="Content-Language"/>
#   <link rel="preconnect" src="https://cdn.evbstatic.com"/>
#   <link rel="dns-prefetch" src="https://cdn.evbstatic.com"/>
#   <link rel="preconnect" src="https://img.evbuc.com"/>
#   <link rel="dns-prefetch" src="https://img.evbuc.com"/>
#   <link rel="preconnect" src="https://cdn.transcend.io"/>
#   <link rel="dns-prefetch" src="https://cdn.transcend.io"/>
#   <link rel="preconnect" src="https://cdn.branch.io"/>
#   <link rel="dns-prefetch" src="https://cdn.branch.io"/>
#   <link rel="preconnect" src="https://www.googletagmanager.com"/>
#   <link rel="dns-prefetch" src="https://www.googletagmanager.com"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/favicon.ico" rel="shortcut icon"/>
#   <link color="#f6682f" href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="Eventbrite" name="apple-mobile-web-app-title"/>
#   <meta content="Eventbrite" name="application-name"/>
#   <meta content="#f6682f" name="msapplication-TileColor"/>
#   <meta content="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#f6682f" name="theme-color"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/touch_icons/apple-touch-icon-180x180.png" rel="apple-touch-icon"/>
#   <link href="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/favicons/manifest.webmanifest" rel="manifest"/>
#   <meta content="d92e23811007b438" name="y_key"/>
#   <meta content="A9AB07B7E430E4608E0BC57AFA5004AA" name="msvalidate.01"/>
#   <meta content="28218816837" property="fb:app_id"/>
#   <meta content="Eventbrite" property="og:site_name"/>
#   <meta content="https://cdn.evbstatic.com/s3-build/prod/1475200-rc2023-12-19_16.04-3940058/django/images/logos/eb_orange_on_white_1200x630.png" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="1200" property="og:image:height"/>
#   <meta content="United States All Events | Eventbrite" property="og:title"/>
#   <meta content="Looking for the best that your city has to offer?         Visit Eventbrite to find your next experience - whether         it's a 5k race, a web design class, a food festival or more." property="og:description"/>
#   <meta content="https://www.eventbrite.com/d/united-states/all-events/?page=4" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <!--The default time to live is 7 days, we are bumping to 9 days to test if this reduces crawler traffic,
#     documented in ticket EB-85484-->
#   <meta content="777600" property="og:ttl"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@eventbrite" name="twitter:site"/>
#   <meta content="United States All Events | Eventbrite" name="twitter:title"/>
#   <meta content="Looking for the best that your city has to offer?         Visit Eventbrite to find your next experience - whether         it's a 5k race, a web design class, a food festival or more." name="twitter:description"/>
#   <script type="text/javascript">
#    window.EBFONTCOND_PROPERTIES = {
#         family: "Neue Plak Condensed",
#         src: "https://cdn.evbstatic.com/s3-build/perm_001/dfcae5/django/js/src/eb/fonts/neueplak-condensed.js",
#         oldVersions: [
#             "EB.fonts.neueplak-condensed.12-01-2018",
#             "EB.fonts.neueplak-condensed.12-03-2018",
#         ],
#         version: "EB.fonts.neueplak-condensed.08-22-2023",
#     };
#
#     window.EBFONT_PROPERTIES = {
#         family: "Neue Plak",
#         src: "https://cdn.evbstatic.com/s3-build/perm_001/01489c/django/js/src/eb/fonts/neueplak.js",
#         oldVersions: [
#             "EB.fonts.neueplak.03-19-2019",
#             "EB.fonts.neueplak.10-24-2018",
#             "EB.fonts.neueplak.09-20-2018",
#             "EB.fonts.neueplak.09-04-2018",
#             "EB.fonts.neueplak.08-30-2018",
#             "EB.fonts.neueplak.08-24-2018",
#             "EB.fonts.benton.10-26-2016",
#             "EB.fonts.benton.11-29-2016",
#         ],
#         version: "EB.fonts.neueplak.08-22-2023",
#     };
#   </script>
#   <script charset="utf-8" crossorigin="anonymous" type="text/javascript">
#    /* eslint-disable */
# !function(a,b){a.EB=a.EB||{},EB.renderFonts=function(c,d){d||(d=a.EBFONT_PROPERTIES.family);for(var e="",f=b.createElement("style"),g=0,h;h=c[g];g++)e+="@font-face{font-family:'"+d+"';font-weight:"+h.weight+";font-style:"+h.style+";src:url(data:application/font-woff;base64,"+h.base64+") format('woff');}";f.styleSheet&&!f.sheet?f.styleSheet.cssText=e:f.appendChild(b.createTextNode(e)),b.getElementsByTagName("head")[0].appendChild(f),b.documentElement.className+=" font-has-loaded"},EB.readWriteFontFromLocalStorage=function(a){for(var c=0;c<a.oldVersions.length;c++)localStorage.removeItem(a.oldVersions[c]);var d=JSON.parse(localStorage.getItem(a.version));if(d)EB.renderFonts(d,a.family);else{var e=b.createElement("script");e.src=a.src,EB.shouldRenderFonts=!0,EB.shouldRenderSecondaryFonts=!0,b.getElementsByTagName("head")[0].appendChild(e),setTimeout(function(){EB.shouldRenderFonts=!1,EB.shouldRenderSecondaryFonts=!1},3e3)}};try{if(a.localStorage)try{localStorage.setItem("localStorage",1),localStorage.removeItem("localStorage"),EB.readWriteFontFromLocalStorage(a.EBFONT_PROPERTIES),EB.readWriteFontFromLocalStorage(a.EBFONTCOND_PROPERTIES)}catch(c){Storage.prototype._setItem=Storage.prototype.setItem,Storage.prototype.setItem=function(){}}}catch(d){}}(window,document);
#   </script>
#   <link href="https://cdn.evbstatic.com/s3-build/fe/build/discover--9.8.0--eds-3.1.25.css" rel="stylesheet" type="text/css"/>
#   <link data-chunk="discover" href="https://cdn.evbstatic.com/s3-build/fe/build/discover.4f68011b04fe50c7ed4e.css" rel="stylesheet"/>
#   <link data-chunk="search" href="https://cdn.evbstatic.com/s3-build/fe/build/1950.a6918c86fe21d416ea79.css" rel="stylesheet"/>
#   <link data-chunk="search" href="https://cdn.evbstatic.com/s3-build/fe/build/8815.6ecf42c9ed734652a77c.css" rel="stylesheet"/>
#   <link data-chunk="search" href="https://cdn.evbstatic.com/s3-build/fe/build/6464.b5b4b2122bc0403a4011.css" rel="stylesheet"/>
#   <link data-chunk="FilterPanelContainer" href="https://cdn.evbstatic.com/s3-build/fe/build/860.33cc5cbfbe2dca228c49.css" rel="stylesheet"/>
#   <link data-chunk="Vertical-DiscoverVerticalSearchEventCard" href="https://cdn.evbstatic.com/s3-build/fe/build/6981.5ae799b8da2d01601eff.css" rel="stylesheet"/>
#   <link data-chunk="Horizontal-DiscoverHorizontalEventCard" href="https://cdn.evbstatic.com/s3-build/fe/build/4535.0308e005dcd130fed13b.css" rel="stylesheet"/>
#   <link data-chunk="components-ThingsToDoShelf" href="https://cdn.evbstatic.com/s3-build/fe/build/4093.f1387c222ff5e16a89f7.css" rel="stylesheet"/>
#   <script>
#    /*global document, window */
#
# var checkoutExternalUrls = [
#     '/checkout-external',
#     '/tickets-external',
#     '/signin/checkout',
# ];
#
# window.EB = window.EB || {};
#
# window.EB.TranscendConsent = (function () {
#     return {
#         shouldDisableTranscend: function () {
#             if(this.isEmbeddableContent()){
#                 return true;
#             }
#             try {
#                 return this.isCheckoutOrIframe();
#             } catch (e) {
#                 return true;
#             }
#         },
#         isEmbeddableContent: function () {
#             return this.isEmbeddableStructuredContent();
#         },
#         isEmbeddableStructuredContent: function () {
#             var structuredContenEmbeddableUrls = [
#                 '/structured_content/widgets',
#             ];
#             if(structuredContenEmbeddableUrls.find(function(url){
#                 return window.location.pathname.indexOf(url) !== -1;
#             })){
#                 return true;
#             }
#             return false;
#         },
#         isCheckoutOrIframe: function () {
#             return (
#                 checkoutExternalUrls.indexOf(window.location.pathname) >= 0 ||
#                 this.isInsideIframe()
#             );
#         },
#         isInsideIframe: function () {
#             try {
#                 return window.self !== window.top;
#             } catch (e) {
#                 return true;
#             }
#         },
#         isNonTld: function () {
#             try {
#                 return !['evbdev', 'evbqa', 'eventbrite'].find(
#                     (env) => window.parent.location.hostname.indexOf(env) >= 0,
#                 );
#             } catch (e) {
#                 return true;
#             }
#         },
#         isInsideNonTldIframe: function () {
#             return this.isInsideIframe() && this.isNonTld();
#         },
#     };
# })();
#   </script>
#   <script type="text/javascript">
#    // Define dataLayer and the gtag function.
#     window.dataLayer = window.dataLayer || [];
#     if (typeof gtag !== 'function') function gtag(){ dataLayer.push(arguments); }
#     gtag('set', 'developer_id.dOGRkZj', true);
#
#     // Europe is opt-in consent, so ad storage is denied by default.
#     gtag('consent', 'default', {
#         'ad_storage': 'granted',
#         'analytics_storage': 'granted',
#         'region': ['AT','BE','BG','CZ','DE','DK','ES','FI','FR','GB','GR','HU','IE','IT','LU','NL','PL','PT','RO','SE','BR','TH','TR'],
#         'wait_for_update': 500
#     });
#
#     // Passing ad click, client ID, and session ID information in URLs
#     gtag('set', 'url_passthrough', true);
#   </script>
#   <!-- Transcend Consent Airgap Code-->
#   <script data-cfasync="false" data-ui-z-index="550" src="https://cdn.transcend.io/cm/f2747157-cf59-4ef1-8703-018defe51764/airgap.js">
#   </script>
#   <!-- END Transcend Consent Airgap Code -->
#   <script>
#    const regimes = window.airgap && window.airgap.getRegimes ? window.airgap.getRegimes() : null;
#     const defaultRegime = regimes ? regimes.values().next().value : "CPRA";
#     console.log("Regime detected is "+ defaultRegime + ", loading transcend")
#     if (!EB.TranscendConsent.shouldDisableTranscend()) {
#             console.log("Show banner")
#             transcend.autoShowConsentManager();
#     }else{
#             console.log("Do not show banner")
#     }
#     dataLayer.push({ event: "transcendLoaded" });
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
#         (function() {
#             var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.defer = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#         })();
#
#         var _gaq = _gaq || [];
#         //]]>
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#             ga('create', 'UA-141520-1', {'allowLinker': true, 'cookieFlags': 'SameSite=None; Secure' }, 'auto');
#
#
#
#             ga('set', 'forceSSL', true);
#   </script>
#   <!-- Google Tag Manager - Eventbrite - Main container-->
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#                 dataLayer.push({
#                     'dfaPartnerID': 'dfa_partner_id_not_set',
#                     'publicUserID': ''
#                 });
#
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5P8FXJ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <link href="https://www.eventbrite.com/d/united-states/all-events/?page=4" rel="canonical"/>
#   <link href="?page=3" rel="prev"/>
#   <link href="?page=5" rel="next"/>
#   <script type="text/javascript">
#    var customActions = {
#         SaveClicked: 'save_event',
#     };
#     var branchMedatata = { metadata : {} };
#     //Adding user authenticated metatag
#
#     (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.defer=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#         branch.init('key_live_epYrpbv3NngOvWj47OM81jmgCFkeYUlx' , branchMedatata, function(err, data) {branch.addListener(branchListener);});
#
#     function branchListener(eventName, data) {
#
#         var eventsToTrack = [
#             'didShowJourney',
#             'didClickJourneyCTA',
#             'didClickJourneyClose',
#         ]; // List of events to track
#
#         if (eventName && data && data.journey_link_data && eventsToTrack.includes(eventName)){
#             var journeyName = data.journey_link_data.journey_name + ' - ' + data.journey_link_data.view_name +' - ' + data.journey_link_data.journey_id;
#             trackEventBranchIO(eventName, journeyName);
#         }
#     }
#
#     function trackEventBranchIO(eventName, journeyName){
#
#         if(window && window.dataLayer){
#             window.dataLayer.push({
#             eventName, eventData: { journeyName },
#             // Required:
#             event: "track",
#             sendToHeap: true
#             });
#
#         };
#     }
#
#     function addBranchIOMetatags(
#         name,
#         content,
#         extraData = null,
#     ){
#
#         var metadata = {
#             [name]: content,
#             custom_action: customActions[name] ? customActions[name] : name,
#         };
#
#         //Keep userAuthenticated metadata
#
#         //Adding metadata
#         addMetadata(metadata);
#
#         //Add extra data
#         extraData && addMetadata(extraData);
#
#         branch.track('pageview');
#     }
#
#    function addMetadata(branchData){
#         if (document) {
#             Object.entries(branchData).forEach(([key, value]) => {
#                 const meta = document.createElement('meta');
#                 meta.content = value;
#                 meta.name = 'branch:deeplink:' + key;
#                 document.head.appendChild(meta);
#             });
#         }
#     }
#   </script>
#   <meta content="noindex, follow, " name="robots"/>
#   <meta content="Looking for the best that your city has to offer?         Visit Eventbrite to find your next experience - whether         it's a 5k race, a web design class, a food festival or more." name="description"/>
#   <meta content="initial-scale=1, width=device-width" name="viewport"/>
#   <link href="https://www.eventbrite.com/d/united-states/all-events/?page=4" hreflang="en-us" rel="alternate"/>
#   <link href="https://www.eventbrite.ca/d/united-states/all-events/?page=4" hreflang="en-ca" rel="alternate"/>
#   <link href="https://www.eventbrite.ca/fr_CA/d/united-states/all-events/?page=4" hreflang="fr-ca" rel="alternate"/>
#   <link href="https://www.eventbrite.com.ar/d/united-states/all-events/?page=4" hreflang="es-ar" rel="alternate"/>
#   <link href="https://www.eventbrite.com.br/d/united-states/all-events/?page=4" hreflang="pt-br" rel="alternate"/>
#   <link href="https://www.eventbrite.cl/d/united-states/all-events/?page=4" hreflang="es-cl" rel="alternate"/>
#   <link href="https://www.eventbrite.com.mx/d/united-states/all-events/?page=4" hreflang="es-mx" rel="alternate"/>
#   <link href="https://www.eventbrite.com.pe/d/united-states/all-events/?page=4" hreflang="es-pe" rel="alternate"/>
#   <link href="https://www.eventbrite.co/d/united-states/all-events/?page=4" hreflang="es-co" rel="alternate"/>
#   <link href="https://www.eventbrite.co.uk/d/united-states/all-events/?page=4" hreflang="en-gb" rel="alternate"/>
#   <link href="https://www.eventbrite.ie/d/united-states/all-events/?page=4" hreflang="en-ie" rel="alternate"/>
#   <link href="https://www.eventbrite.de/d/united-states/all-events/?page=4" hreflang="de-de" rel="alternate"/>
#   <link href="https://www.eventbrite.at/d/united-states/all-events/?page=4" hreflang="de-at" rel="alternate"/>
#   <link href="https://www.eventbrite.nl/d/united-states/all-events/?page=4" hreflang="nl-nl" rel="alternate"/>
#   <link href="https://www.eventbrite.be/d/united-states/all-events/?page=4" hreflang="nl-be" rel="alternate"/>
#   <link href="https://www.eventbrite.es/d/united-states/all-events/?page=4" hreflang="es-es" rel="alternate"/>
#   <link href="https://www.eventbrite.fr/d/united-states/all-events/?page=4" hreflang="fr-fr" rel="alternate"/>
#   <link href="https://www.eventbrite.be/fr_BE/d/united-states/all-events/?page=4" hreflang="fr-be" rel="alternate"/>
#   <link href="https://www.eventbrite.it/d/united-states/all-events/?page=4" hreflang="it-it" rel="alternate"/>
#   <link href="https://www.eventbrite.pt/d/united-states/all-events/?page=4" hreflang="pt-pt" rel="alternate"/>
#   <link href="https://www.eventbrite.se/d/united-states/all-events/?page=4" hreflang="sv-se" rel="alternate"/>
#   <link href="https://www.eventbrite.com.au/d/united-states/all-events/?page=4" hreflang="en-au" rel="alternate"/>
#   <link href="https://www.eventbrite.co.nz/d/united-states/all-events/?page=4" hreflang="en-nz" rel="alternate"/>
#   <link href="https://www.eventbrite.sg/d/united-states/all-events/?page=4" hreflang="en-sg" rel="alternate"/>
#   <link href="https://www.eventbrite.hk/d/united-states/all-events/?page=4" hreflang="en-hk" rel="alternate"/>
#   <link href="https://www.eventbrite.dk/d/united-states/all-events/?page=4" hreflang="en-dk" rel="alternate"/>
#   <link href="https://www.eventbrite.fi/d/united-states/all-events/?page=4" hreflang="en-fi" rel="alternate"/>
#   <link href="https://www.eventbrite.ch/d/united-states/all-events/?page=4" hreflang="de-ch" rel="alternate"/>
#   <link href="https://www.eventbrite.ch/fr_CH/d/united-states/all-events/?page=4" hreflang="fr-ch" rel="alternate"/>
#   <link href="https://www.eventbrite.com/d/united-states/all-events/?page=4" hreflang="x-default" rel="alternate"/>
#  </head>
#  <body class="">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5P8FXJ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="eds-g-grid eds-l-mar-top-2 eds-l-mar-bot-2 eds-hide" id="unsupported-browser-alert">
#    <div class="eds-g-cell eds-g-cell-1-1">
#     <div class="eds-notification-bar eds-notification-bar--warning">
#      <span>
#       Your version of Internet Explorer is not longer supported. Please
#       <a href="/support/articles/en_US/Troubleshooting/how-to-troubleshoot-internet-browser-issues" target="_blank">
#        upgrade your browser
#       </a>
#       .
#      </span>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    function isItIE() {
# 	  user_agent = navigator.userAgent;
# 	  var is_it_ie = user_agent.indexOf("MSIE ") > -1 || user_agent.indexOf("Trident/") > -1;
# 	  return is_it_ie;
# 	}
# 	if (isItIE()){
#         var alert = document.getElementById('unsupported-browser-alert');
#         var newClasses = alert.className.split('eds-hide').join('');
#         alert.className = newClasses;
# 	}
#   </script>
#   <div id="root">
#    <div class="eds-structure eds-structure--min-height" data-spec="eds-structure">
#     <div class="eds-structure__header">
#      <header class="GlobalNav-module__main___jfEt2">
#       <nav aria-label="Main Desktop" class="DesktopNav-module__main___2F3A7" data-testid="desktop-nav">
#        <ul class="DesktopNav-module__list___3CVxN">
#         <li class="DesktopNav-module__logo___3nzCH" tabindex="-1">
#          <a aria-label="Home" class="Logo-module__desktop___34U8a" data-heap-id="seo-global-nav-logo-desktop-click" href="https://www.eventbrite.com/" style="background-color:transparent" tabindex="0">
#           <i class="eds-vector-image eds-brand--small eds-vector-image--ui-orange eds-vector-image--block eds-vector-image-size--reset" data-spec="icon" data-testid="icon" style="height:auto;width:110px" title="Eventbrite">
#            <svg viewbox="0 0 200 36">
#             <g fill-rule="evenodd">
#              <g>
#               <g transform="translate(.347)">
#                <path d="M185.945 17.513c2.693-.61 5.381.495 6.878 2.584l-11.905 2.693c.411-2.52 2.333-4.668 5.027-5.277zm6.944 9.91a6.57 6.57 0 01-3.979 2.679c-2.711.614-5.417-.51-6.908-2.626l11.942-2.702 1.945-.44 3.719-.841a11.782 11.782 0 00-.31-2.372c-1.513-6.426-8.055-10.432-14.611-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.61 8.95 3.864-.875 6.869-3.46 8.377-6.751l-5.655-1.269z">
#                </path>
#                <path d="M164.788 35.118V18.082h-3.677v-5.804h3.677V4.289h6.244v7.989h4.69v5.804h-4.69v17.036z" id="logo-wordmark-brand_svg__Fill-10">
#                </path>
#                <path d="M152.86 35.118h6.03v-22.84h-6.03v22.84zm-.785-30.853c0-2.114 1.667-3.7 3.825-3.7 2.157 0 3.775 1.586 3.775 3.7 0 2.115-1.618 3.748-3.775 3.748-2.158 0-3.825-1.633-3.825-3.748zM150.76 12.342c-3.082.16-4.9.633-6.75 1.973v-2.037h-6.026v22.84h6.026v-11.2c0-3.524.86-5.529 6.75-5.726v-5.85zM117.16 24.057c.15 3.333 3.051 6.128 6.602 6.128 3.601 0 6.552-2.942 6.552-6.422 0-3.432-2.95-6.373-6.552-6.373-3.551 0-6.452 2.843-6.602 6.128v.539zm-5.88 11.061V1.38l6.03-1.364v13.962c1.863-1.49 4.07-2.115 6.472-2.115 6.864 0 12.355 5.286 12.355 11.918 0 6.583-5.491 11.965-12.355 11.965-2.403 0-4.609-.624-6.472-2.114v1.487h-6.03z">
#                </path>
#                <path d="M98.445 35.118V17.965h-3.677v-5.687h3.677V4.283l6.244-1.413v9.408h4.69v5.687h-4.69v17.153z" id="logo-wordmark-brand_svg__Fill-1">
#                </path>
#                <path d="M87.394 35.118V22.915c0-4.421-2.402-5.382-4.805-5.382-2.402 0-4.805.913-4.805 5.286v12.299h-6.03v-22.84h6.03v1.699c1.324-.961 2.942-2.115 6.13-2.115 5.098 0 9.51 2.932 9.51 10.092v13.164h-6.03zM56.484 17.513c2.694-.61 5.382.495 6.878 2.584L51.458 22.79c.41-2.52 2.332-4.668 5.026-5.277zm6.945 9.91a6.57 6.57 0 01-3.98 2.679c-2.711.614-5.416-.51-6.907-2.626l11.942-2.702 1.944-.44 3.72-.841a11.782 11.782 0 00-.31-2.372c-1.514-6.426-8.056-10.432-14.612-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.611 8.95 3.863-.875 6.868-3.46 8.376-6.751l-5.654-1.269z">
#                </path>
#                <path d="M31.89 35.118l-9.364-22.84h6.57l5.932 15.49 5.982-15.49h6.57l-9.365 22.84z" id="logo-wordmark-brand_svg__Fill-2">
#                </path>
#                <path d="M10.703 17.507c2.694-.61 5.382.495 6.878 2.584L5.677 22.785c.41-2.52 2.332-4.668 5.026-5.278zm6.945 9.91a6.57 6.57 0 01-3.98 2.68c-2.71.613-5.416-.51-6.907-2.626l11.942-2.702 1.945-.44 3.718-.842a11.782 11.782 0 00-.31-2.371c-1.513-6.426-8.055-10.433-14.61-8.95C2.888 13.65-1.2 20.063.314 26.489c1.514 6.426 8.055 10.432 14.611 8.949 3.864-.874 6.869-3.46 8.376-6.75l-5.654-1.27z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </svg>
#            <span class="eds-is-hidden-accessible">
#             Eventbrite
#            </span>
#           </i>
#          </a>
#          <a aria-label="Home" class="Logo-module__mobile___2HSZd" data-heap-id="seo-global-nav-logo-mobile-click" href="https://www.eventbrite.com/" style="background-color:transparent" tabindex="0">
#           <i class="eds-vector-image eds-brand--small eds-vector-image--ui-orange eds-vector-image--block eds-vector-image-size--reset" data-spec="icon" data-testid="icon" style="height:24px;width:24px" title="Eventbrite">
#            <svg viewbox="0 0 100 98">
#             <g fill-rule="evenodd">
#              <g>
#               <g>
#                <path d="M44.053 23.401c10.985-2.481 21.946 2.016 28.049 10.52L23.556 44.89C25.23 34.627 33.068 25.882 44.053 23.4zm28.32 40.35c-3.67 5.322-9.329 9.35-16.227 10.908-11.057 2.498-22.09-2.076-28.169-10.69l48.698-11.002 7.931-1.792 15.165-3.426a47.9 47.9 0 00-1.263-9.656C92.336 11.931 65.658-4.382 38.923 1.658 12.188 7.698-4.482 33.804 1.691 59.967c6.172 26.162 32.85 42.475 59.585 36.435 15.753-3.559 28.007-14.085 34.156-27.484l-23.059-5.167z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </svg>
#            <span class="eds-is-hidden-accessible">
#             Eventbrite
#            </span>
#           </i>
#          </a>
#         </li>
#         <li class="DesktopNav-module__searchBar___3s7h1">
#         </li>
#         <li class="DesktopNav-module__items___24x2Q">
#          <ul class="NavItemList-module__main___2dzv5">
#           <li class="NavItemList-module__list___3ST1Z">
#            <a aria-label="link" class="NavLink-module__main___3_J-1" data-heap-id="seo-global-nav-link-find-events-click" data-testid="navLink" href="https://www.eventbrite.com/d/local/events/">
#             <span>
#              Find Events
#             </span>
#            </a>
#           </li>
#           <li class="NavItemList-module__list___3ST1Z">
#            <a aria-label="link" class="NavLink-module__main___3_J-1" data-heap-id="seo-global-nav-link-create-events-click" data-testid="navLink" href="https://www.eventbrite.com/organizer/overview/">
#             <span>
#              Create Events
#             </span>
#            </a>
#           </li>
#           <li class="NavItemList-module__list___3ST1Z">
#            <div class="DesktopDropdown-module__desktopDropdown___3gKQx" data-heap-id="seo-global-nav-dropdown-help-center-click" tabindex="0">
#             <div class="DesktopDropdown-module__dropdownTitle___2KDQX">
#              <span>
#               Help Center
#              </span>
#              <span class="DesktopDropdown-module__arrowIcons___21W5p">
#               <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                <svg id="chevron-up-chunky_svg__eds-icon--chevron-up-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                 <path clip-rule="evenodd" d="M17 13.8l-5-5-5 5 1.4 1.4 3.6-3.6 3.6 3.6z" fill-rule="evenodd" id="chevron-up-chunky_svg__eds-icon--chevron-up-chunky_base">
#                 </path>
#                </svg>
#               </i>
#               <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                <svg id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                 <path clip-rule="evenodd" d="M7 10.2l5 5 5-5-1.4-1.4-3.6 3.6-3.6-3.6z" fill-rule="evenodd" id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_base">
#                 </path>
#                </svg>
#               </i>
#              </span>
#             </div>
#             <ul aria-label="submenu" class="Dropdown-module__dropdown___3wMWo" data-testid="global-nav-dropdown">
#              <li class="Dropdown-module__navLinkContainer___IFjfQ" data-testid="link-container__level1">
#               <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown nav-link__dropdpown__level1" data-heap-id="seo-global-nav-link-help-center-click" data-testid="navLink" href="https://www.eventbrite.com/help/">
#                <span>
#                 Help Center
#                </span>
#               </a>
#              </li>
#              <li class="Dropdown-module__navLinkContainer___IFjfQ" data-testid="link-container__level1">
#               <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown nav-link__dropdpown__level1" data-heap-id="seo-global-nav-link-find-your-tickets-click" data-testid="navLink" href="https://www.eventbrite.com/help/en-us/articles/319355/where-are-my-tickets/">
#                <span>
#                 Find your tickets
#                </span>
#               </a>
#              </li>
#              <li class="Dropdown-module__navLinkContainer___IFjfQ" data-testid="link-container__level1">
#               <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown nav-link__dropdpown__level1" data-heap-id="seo-global-nav-link-contact-your-event-organizer-click" data-testid="navLink" href="https://www.eventbrite.com/help/en-us/articles/647151/how-to-contact-the-event-organizer/">
#                <span>
#                 Contact your event organizer
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </li>
#           <li class="NavItemList-module__list___3ST1Z">
#            <a aria-label="link" class="NavLink-module__main___3_J-1 NavItemList-module__login___21v8M" data-heap-id="seo-global-nav-link-login-click" data-testid="navLink" href="https://www.eventbrite.com/signin/?referrer=%2Fd%2Funited-states%2Fall-events%2F%3Fpage%3D4">
#             <span>
#              Log In
#             </span>
#            </a>
#           </li>
#           <li class="NavItemList-module__list___3ST1Z">
#            <a aria-label="link" class="NavLink-module__main___3_J-1 NavItemList-module__signup___1wTwG" data-heap-id="seo-global-nav-link-signup-click" data-testid="navLink" href="https://www.eventbrite.com/signin/signup/?referrer=%2Fd%2Funited-states%2Fall-events%2F%3Fpage%3D4">
#             <span>
#              Sign Up
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </nav>
#       <nav aria-label="Main Mobile" class="MobileNav-module__nav___1guDW MobileNav-module__navHeight___X8FEo" data-testid="mobile-nav">
#        <ul class="MobileNav-module__root___AeDQc">
#         <li class="MobileNav-module__logo___2fnbq">
#          <a aria-label="Home" class="Logo-module__desktop___34U8a" data-heap-id="seo-global-nav-logo-desktop-click" href="https://www.eventbrite.com/" style="background-color:transparent" tabindex="0">
#           <i class="eds-vector-image eds-brand--small eds-vector-image--ui-orange eds-vector-image--block eds-vector-image-size--reset" data-spec="icon" data-testid="icon" style="height:auto;width:110px" title="Eventbrite">
#            <svg viewbox="0 0 200 36">
#             <g fill-rule="evenodd">
#              <g>
#               <g transform="translate(.347)">
#                <path d="M185.945 17.513c2.693-.61 5.381.495 6.878 2.584l-11.905 2.693c.411-2.52 2.333-4.668 5.027-5.277zm6.944 9.91a6.57 6.57 0 01-3.979 2.679c-2.711.614-5.417-.51-6.908-2.626l11.942-2.702 1.945-.44 3.719-.841a11.782 11.782 0 00-.31-2.372c-1.513-6.426-8.055-10.432-14.611-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.61 8.95 3.864-.875 6.869-3.46 8.377-6.751l-5.655-1.269z">
#                </path>
#                <path d="M164.788 35.118V18.082h-3.677v-5.804h3.677V4.289h6.244v7.989h4.69v5.804h-4.69v17.036z" id="logo-wordmark-brand_svg__Fill-10">
#                </path>
#                <path d="M152.86 35.118h6.03v-22.84h-6.03v22.84zm-.785-30.853c0-2.114 1.667-3.7 3.825-3.7 2.157 0 3.775 1.586 3.775 3.7 0 2.115-1.618 3.748-3.775 3.748-2.158 0-3.825-1.633-3.825-3.748zM150.76 12.342c-3.082.16-4.9.633-6.75 1.973v-2.037h-6.026v22.84h6.026v-11.2c0-3.524.86-5.529 6.75-5.726v-5.85zM117.16 24.057c.15 3.333 3.051 6.128 6.602 6.128 3.601 0 6.552-2.942 6.552-6.422 0-3.432-2.95-6.373-6.552-6.373-3.551 0-6.452 2.843-6.602 6.128v.539zm-5.88 11.061V1.38l6.03-1.364v13.962c1.863-1.49 4.07-2.115 6.472-2.115 6.864 0 12.355 5.286 12.355 11.918 0 6.583-5.491 11.965-12.355 11.965-2.403 0-4.609-.624-6.472-2.114v1.487h-6.03z">
#                </path>
#                <path d="M98.445 35.118V17.965h-3.677v-5.687h3.677V4.283l6.244-1.413v9.408h4.69v5.687h-4.69v17.153z" id="logo-wordmark-brand_svg__Fill-1">
#                </path>
#                <path d="M87.394 35.118V22.915c0-4.421-2.402-5.382-4.805-5.382-2.402 0-4.805.913-4.805 5.286v12.299h-6.03v-22.84h6.03v1.699c1.324-.961 2.942-2.115 6.13-2.115 5.098 0 9.51 2.932 9.51 10.092v13.164h-6.03zM56.484 17.513c2.694-.61 5.382.495 6.878 2.584L51.458 22.79c.41-2.52 2.332-4.668 5.026-5.277zm6.945 9.91a6.57 6.57 0 01-3.98 2.679c-2.711.614-5.416-.51-6.907-2.626l11.942-2.702 1.944-.44 3.72-.841a11.782 11.782 0 00-.31-2.372c-1.514-6.426-8.056-10.432-14.612-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.611 8.95 3.863-.875 6.868-3.46 8.376-6.751l-5.654-1.269z">
#                </path>
#                <path d="M31.89 35.118l-9.364-22.84h6.57l5.932 15.49 5.982-15.49h6.57l-9.365 22.84z" id="logo-wordmark-brand_svg__Fill-2">
#                </path>
#                <path d="M10.703 17.507c2.694-.61 5.382.495 6.878 2.584L5.677 22.785c.41-2.52 2.332-4.668 5.026-5.278zm6.945 9.91a6.57 6.57 0 01-3.98 2.68c-2.71.613-5.416-.51-6.907-2.626l11.942-2.702 1.945-.44 3.718-.842a11.782 11.782 0 00-.31-2.371c-1.513-6.426-8.055-10.433-14.61-8.95C2.888 13.65-1.2 20.063.314 26.489c1.514 6.426 8.055 10.432 14.611 8.949 3.864-.874 6.869-3.46 8.376-6.75l-5.654-1.27z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </svg>
#            <span class="eds-is-hidden-accessible">
#             Eventbrite
#            </span>
#           </i>
#          </a>
#          <a aria-label="Home" class="Logo-module__mobile___2HSZd" data-heap-id="seo-global-nav-logo-mobile-click" href="https://www.eventbrite.com/" style="background-color:transparent" tabindex="0">
#           <i class="eds-vector-image eds-brand--small eds-vector-image--ui-orange eds-vector-image--block eds-vector-image-size--reset" data-spec="icon" data-testid="icon" style="height:24px;width:24px" title="Eventbrite">
#            <svg viewbox="0 0 100 98">
#             <g fill-rule="evenodd">
#              <g>
#               <g>
#                <path d="M44.053 23.401c10.985-2.481 21.946 2.016 28.049 10.52L23.556 44.89C25.23 34.627 33.068 25.882 44.053 23.4zm28.32 40.35c-3.67 5.322-9.329 9.35-16.227 10.908-11.057 2.498-22.09-2.076-28.169-10.69l48.698-11.002 7.931-1.792 15.165-3.426a47.9 47.9 0 00-1.263-9.656C92.336 11.931 65.658-4.382 38.923 1.658 12.188 7.698-4.482 33.804 1.691 59.967c6.172 26.162 32.85 42.475 59.585 36.435 15.753-3.559 28.007-14.085 34.156-27.484l-23.059-5.167z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </svg>
#            <span class="eds-is-hidden-accessible">
#             Eventbrite
#            </span>
#           </i>
#          </a>
#         </li>
#         <li class="MobileNav-module__searchBar___3hIV-">
#         </li>
#         <li class="MobileNav-module__right___2JpIc">
#          <ul class="MobileNav-module__linkContainer___21XwL">
#           <li class="MobileNav-module__listLink___1OAO5">
#            <a aria-label="link" class="NavLink-module__main___3_J-1 MobileNav-module__login___297iq" data-heap-id="seo-global-nav-link-login-click" data-testid="navLink" href="https://www.eventbrite.com/signin/?referrer=%2Fd%2Funited-states%2Fall-events%2F%3Fpage%3D4">
#             <span>
#              Log In
#             </span>
#            </a>
#           </li>
#           <li class="MobileNav-module__listLink___1OAO5">
#            <a aria-label="link" class="NavLink-module__main___3_J-1 MobileNav-module__signup___3539W" data-heap-id="seo-global-nav-link-signup-click" data-testid="navLink" href="https://www.eventbrite.com/signin/signup/?referrer=%2Fd%2Funited-states%2Fall-events%2F%3Fpage%3D4">
#             <span>
#              Sign Up
#             </span>
#            </a>
#           </li>
#           <li class="MobileDropdown-module__mobileDropdown___1-DuJ" data-heap-id="seo-global-nav-dropdown-mobile-click" tabindex="0">
#            <i aria-hidden="true" class="Icon_root__mu5dq Icon_icon-small__mu5dq">
#             <svg fill="#3A3247" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path clip-rule="evenodd" d="M20 5H4v2h16V5ZM4 11h16v2H4v-2Zm0 6h16v2H4v-2Z">
#              </path>
#             </svg>
#            </i>
#            <i aria-hidden="true" class="Icon_root__mu5dq Icon_icon-small__mu5dq">
#             <svg fill="#3A3247" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="m13.4 12 3.5-3.5-1.4-1.4-3.5 3.5-3.5-3.5-1.4 1.4 3.5 3.5-3.5 3.5 1.4 1.4 3.5-3.5 3.5 3.5 1.4-1.4z">
#              </path>
#             </svg>
#            </i>
#            <ul aria-label="submenu" class="Dropdown-module__dropdown___3wMWo" data-testid="global-nav-dropdown">
#             <li class="Dropdown-module__navLinkContainer___IFjfQ" data-testid="link-container__level1">
#              <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown nav-link__dropdpown__level1" data-heap-id="seo-global-nav-link-find-events-click" data-testid="navLink" href="https://www.eventbrite.com/d/local/events/">
#               <span class="" data-testid="navLink-icon">
#                <i aria-hidden="true" class="Icon_root__mu5dq Icon_icon-small__mu5dq">
#                 <i aria-hidden="true" class="Icon_root__mu5dq Icon_icon-small__mu5dq">
#                  <svg fill="#3A3247" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                   <path clip-rule="evenodd" d="M10 13h4v-2h-4v2Zm6 5h-.413c-.603-1.437-1.833-2.424-3.587-2.424-1.754 0-2.984.987-3.587 2.424H8V6h.413C9.016 7.437 10.246 8.424 12 8.424c1.754 0 2.984-.987 3.587-2.424H16v12ZM14 4s0 2.424-2 2.424S10 4 10 4H6v16h4s0-2.424 2-2.424S14 20 14 20h4V4h-4Z">
#                   </path>
#                  </svg>
#                 </i>
#                </i>
#               </span>
#               <span>
#                Find Events
#               </span>
#              </a>
#             </li>
#             <li class="NestedDropdownItem-module__nestedDropdownTrigger___3e99X" tabindex="-1">
#              <span class="NestedDropdownItem-module__titleContainer___28qcS" data-heap-id="seo-global-nav-dropdown-create-events-click" tabindex="0">
#               <span class="NestedDropdownItem-module__iconContainer___1eN6Z">
#                <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                 <i aria-hidden="true" class="Icon_root__mu5dq Icon_icon-small__mu5dq">
#                  <svg fill="#3A3247" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                   <path clip-rule="evenodd" d="M17 6.5v-2h-2v2H9v-2H7v2H5v13h14v-13h-2Zm0 11H7v-7h10v8-1Z">
#                   </path>
#                  </svg>
#                 </i>
#                </i>
#               </span>
#               <span>
#                Create Events
#               </span>
#               <span class="NestedDropdownItem-module__arrowIcons___2NwH6">
#                <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                 <svg id="chevron-up-chunky_svg__eds-icon--chevron-up-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                  <path clip-rule="evenodd" d="M17 13.8l-5-5-5 5 1.4 1.4 3.6-3.6 3.6 3.6z" fill-rule="evenodd" id="chevron-up-chunky_svg__eds-icon--chevron-up-chunky_base">
#                  </path>
#                 </svg>
#                </i>
#                <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                 <svg id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                  <path clip-rule="evenodd" d="M7 10.2l5 5 5-5-1.4-1.4-3.6 3.6-3.6-3.6z" fill-rule="evenodd" id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_base">
#                  </path>
#                 </svg>
#                </i>
#               </span>
#              </span>
#              <ul aria-label="submenu" class="NestedDropdownItem-module__submenu___3TV4u">
#               <li class="SecondaryDropdown-module__secondaryDropdownTrigger___2tgnG" data-globalnav-text="Solutions" data-heap-id="seo-global-nav-dropdown-solutions-click" tabindex="0">
#                <span class="SecondaryDropdown-module__titleContainer___2j-cS">
#                 <span>
#                  Solutions
#                 </span>
#                 <span class="SecondaryDropdown-module__iconContainer___14tna">
#                  <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                   <svg id="chevron-right-chunky_svg__eds-icon--chevron-right-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                    <path clip-rule="evenodd" d="M10.2 17l5-5-5-5-1.4 1.4 3.6 3.6-3.6 3.6z" fill-rule="evenodd" id="chevron-right-chunky_svg__eds-icon--chevron-right-chunky_base">
#                    </path>
#                   </svg>
#                  </i>
#                 </span>
#                </span>
#                <ul class="SecondaryDropdown-module__secondaryDropdown___3kH0U">
#                 <button tabindex="0">
#                  <svg id="chevron-left-chunky_svg__eds-icon--chevron-left-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                   <path clip-rule="evenodd" d="M13.8 7l-5 5 5 5 1.4-1.4-3.6-3.6 3.6-3.6z" fill-rule="evenodd" id="chevron-left-chunky_svg__eds-icon--chevron-left-chunky_base">
#                   </path>
#                  </svg>
#                  Solutions
#                 </button>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-event-ticketing-click" data-testid="navLink" href="https://www.eventbrite.com/l/sell-tickets/">
#                   <span>
#                    Event Ticketing
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-marketing-suite-click" data-testid="navLink" href="https://www.eventbrite.com/l/event-marketing-platform/">
#                   <span>
#                    Event Marketing Platform
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-eventbrite-ads-click" data-testid="navLink" href="https://www.eventbrite.com/l/eventbrite-ads/">
#                   <span>
#                    Eventbrite Ads
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-payments-click" data-testid="navLink" href="https://www.eventbrite.com/l/event-payment/">
#                   <span>
#                    Payments
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="SecondaryDropdown-module__secondaryDropdownTrigger___2tgnG" data-globalnav-text="Industry" data-heap-id="seo-global-nav-dropdown-industry-click" tabindex="0">
#                <span class="SecondaryDropdown-module__titleContainer___2j-cS">
#                 <span>
#                  Industry
#                 </span>
#                 <span class="SecondaryDropdown-module__iconContainer___14tna">
#                  <i aria-hidden="true" class="eds-vector-image eds-icon--small" data-spec="icon" data-testid="icon">
#                   <svg id="chevron-right-chunky_svg__eds-icon--chevron-right-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                    <path clip-rule="evenodd" d="M10.2 17l5-5-5-5-1.4 1.4 3.6 3.6-3.6 3.6z" fill-rule="evenodd" id="chevron-right-chunky_svg__eds-icon--chevron-right-chunky_base">
#                    </path>
#                   </svg>
#                  </i>
#                 </span>
#                </span>
#                <ul class="SecondaryDropdown-module__secondaryDropdown___3kH0U">
#                 <button tabindex="0">
#                  <svg id="chevron-left-chunky_svg__eds-icon--chevron-left-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                   <path clip-rule="evenodd" d="M13.8 7l-5 5 5 5 1.4-1.4-3.6-3.6 3.6-3.6z" fill-rule="evenodd" id="chevron-left-chunky_svg__eds-icon--chevron-left-chunky_base">
#                   </path>
#                  </svg>
#                  Industry
#                 </button>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-music-click" data-testid="navLink" href="https://www.eventbrite.com/l/music/">
#                   <span>
#                    Music
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-food-&amp;-beverage-click" data-testid="navLink" href="https://www.eventbrite.com/l/food-drink-event-ticketing/">
#                   <span>
#                    Food &amp; Beverage
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-performing-arts-click" data-testid="navLink" href="https://www.eventbrite.com/l/performing-arts/">
#                   <span>
#                    Performing Arts
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-charity-&amp;-causes-click" data-testid="navLink" href="https://www.eventbrite.com/l/npo/">
#                   <span>
#                    Charity &amp; Causes
#                   </span>
#                  </a>
#                 </li>
#                 <li class="SecondaryDropdown-module__navLinkContainer___1UKfq">
#                  <a aria-label="link" class="NavLink-module__main___3_J-1 nav-link__dropdown" data-heap-id="seo-global-nav-link-retail-click" data-testid="navLink" href="https://www.eventbrite.com/l/host-retail-events/">
#                   <span>
# ...
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"Seattle New Years Eve Party 2024 | Gatsby's Penthouse","url":"https://www.eventbrite.com/e/seattle-new-years-eve-party-2024-gatsbys-penthouse-tickets-648360903917","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F527551909%2F412671342061%2F1%2Foriginal.20230602-015621?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C2160%2C1080\u0026s=c5d26e90aa4998397f51bb31e245228f","offers":{"url":"https://www.eventbrite.com/e/seattle-new-years-eve-party-2024-gatsbys-penthouse-tickets-648360903917","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Seattle","addressRegion":"WA","streetAddress":"255 S King St","postalCode":"98104","@type":"PostalAddress"},"geo":{"latitude":"47.5980919","@type":"GeoCoordinates","longitude":"-122.3309701"},"@type":"Place","name":"King Street Ballroom \u0026 Perch"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Join us for the most upscale New Year's Eve Party in Seattle, Gatsby's Penthouse! 4hr prepaid bar, top DJs, casino games with prizes \u0026 more!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"2024 Karat Magic: NYE Party","url":"https://www.eventbrite.com/e/2024-karat-magic-nye-party-tickets-764161285977","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F646119279%2F140671170219%2F1%2Foriginal.20231121-200522?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C2160%2C1080\u0026s=fd815d23492736f12715f59a9f96bbaa","offers":{"url":"https://www.eventbrite.com/e/2024-karat-magic-nye-party-tickets-764161285977","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Tampa","addressRegion":"FL","streetAddress":"601 South Harbour Island Boulevard","postalCode":"33602","@type":"PostalAddress"},"geo":{"latitude":"27.9387237","@type":"GeoCoordinates","longitude":"-82.4548811"},"@type":"Place","name":"601 S Harbour Island Blvd"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Ring in 2024 in Downtown Tampa with Tampa's Largest Fireworks Display at American Social!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"TOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+","url":"https://www.eventbrite.com/e/toast-nye-sunday-december-31-2023-at-bamboo-atlanta-21-tickets-770998636677","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F652334519%2F218107036300%2F1%2Foriginal.20231203-053621?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C940%2C470\u0026s=5162b553e7fabb6b93a44a1f86a6ff16","offers":{"url":"https://www.eventbrite.com/e/toast-nye-sunday-december-31-2023-at-bamboo-atlanta-21-tickets-770998636677","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Atlanta","addressRegion":"GA","streetAddress":"183 Forsyth Street Southwest","postalCode":"30303","@type":"PostalAddress"},"geo":{"latitude":"33.7497499","@type":"GeoCoordinates","longitude":"-84.39604829999999"},"@type":"Place","name":"Bamboo atlanta"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Team Litty Presents Toast NYE 2023 Celebration at Bamboo Atlanta! All-new Venue, Bottle Service, Food, Drinks, Hookahs \u0026 Live DJs."}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"New Year's Eve Party by Winter Park Events","url":"https://www.eventbrite.com/e/new-years-eve-party-by-winter-park-events-tickets-722077572457","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F628301489%2F5852276165%2F1%2Foriginal.20231025-150112?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=10%2C0%2C2258%2C1129\u0026s=2b3520f703ca1d3c35b66c7abaf6a73f","offers":{"url":"https://www.eventbrite.com/e/new-years-eve-party-by-winter-park-events-tickets-722077572457","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Winter Park","addressRegion":"FL","streetAddress":"1050 West Morse Boulevard","postalCode":"32789","@type":"PostalAddress"},"geo":{"latitude":"28.5971601","@type":"GeoCoordinates","longitude":"-81.3633723"},"@type":"Place","name":"Winter Park Events Center"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Ring in 2024 in Style! Winter Park's Premier New Year's Eve Party. Special Event: Limited Ticket Availability...."}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2024-01-25","endDate":"2024-01-28","name":"Podfest Expo 2024","url":"https://www.eventbrite.com/e/podfest-expo-2024-tickets-638791581817","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F518637499%2F456703984960%2F1%2Foriginal.20230519-182653?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C2160%2C1080\u0026s=8b44767df13237233678113778c254f1","offers":{"url":"https://www.eventbrite.com/e/podfest-expo-2024-tickets-638791581817","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Orlando","addressRegion":"FL","streetAddress":"8001 International Drive","postalCode":"32819","@type":"PostalAddress"},"geo":{"latitude":"28.4485816","@type":"GeoCoordinates","longitude":"-81.4682744"},"@type":"Place","name":"Wyndham Orlando Resort International Drive"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Connect with other podcasters and content creators by joining our LARGEST EVENT yet! We're celebrating our 10th anniversary of Podfest Expo!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"NYE 2024 Party at sections !","url":"https://www.eventbrite.com/e/nye-2024-party-at-sections-tickets-738868404287","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F642979809%2F60173928473%2F1%2Foriginal.20231116-120757?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026s=e5c3e84003971c1a76babee424bb4a65","offers":{"url":"https://www.eventbrite.com/e/nye-2024-party-at-sections-tickets-738868404287","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Charlotte","addressRegion":"NC","streetAddress":"832 Seigle Avenue","postalCode":"28204","@type":"PostalAddress"},"geo":{"latitude":"35.2256253","@type":"GeoCoordinates","longitude":"-80.824744"},"@type":"Place","name":"Section, Seigle Avenue, Charlotte, NC, USA"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Get ready to ring in the New Year with the wildest party of 2024 at Sections! Join us for an epic in-person celebration that will leave you"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2024-01-14","endDate":"2024-01-14","name":"Houston BBQ Throwdown 2024!","url":"https://www.eventbrite.com/e/houston-bbq-throwdown-2024-tickets-729650061977","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F634823729%2F161088700426%2F1%2Foriginal.20231103-211354?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C67%2C1616%2C808\u0026s=af94e89aa89805863b6772a2c892b112","offers":{"url":"https://www.eventbrite.com/e/houston-bbq-throwdown-2024-tickets-729650061977","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Houston","addressRegion":"TX","streetAddress":"2000 Lyons Avenue","postalCode":"77020","@type":"PostalAddress"},"geo":{"latitude":"29.771119","@type":"GeoCoordinates","longitude":"-95.348566"},"@type":"Place","name":"Saint Arnold Brewing Company - Beer Hall"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Taste the future of Houston Barbecue\nThe\u00a0Houston Barbecue Festival\u00a0\u0026\u00a0Saint Arnold Brewing Company\u00a0announce the Houston BBQ Throwdown!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTA","url":"https://www.eventbrite.com/e/the-greatest-nye-on-earth-2024-revel-atlanta-tickets-755598053117","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F660493999%2F213642457492%2F1%2Foriginal.20231218-225435?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C2160%2C1080\u0026s=c896b987935b719f27b79a0a24554abe","offers":{"url":"https://www.eventbrite.com/e/the-greatest-nye-on-earth-2024-revel-atlanta-tickets-755598053117","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Atlanta","addressRegion":"GA","streetAddress":"1778 Ellsworth Industrial Boulevard Northwest","postalCode":"30318","@type":"PostalAddress"},"geo":{"latitude":"33.8036713","@type":"GeoCoordinates","longitude":"-84.42752009999998"},"@type":"Place","name":"Revel"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Get ready for the most epic New Year's Eve celebration ever in Atlanta!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-30","endDate":"2023-12-30","name":"Night of the Yip-Hoot","url":"https://www.eventbrite.com/e/night-of-the-yip-hoot-tickets-778922818117","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F659878569%2F180412965978%2F1%2Foriginal.20231217-205321?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C2160%2C1080\u0026s=019044230d7e0291962cc7e47d1fd8b3","offers":{"url":"https://www.eventbrite.com/e/night-of-the-yip-hoot-tickets-778922818117","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Brooklyn","addressRegion":"NY","streetAddress":"149 7th Street","postalCode":"11215","@type":"PostalAddress"},"geo":{"latitude":"40.6737185","@type":"GeoCoordinates","longitude":"-73.9916803"},"@type":"Place","name":"The Bell House"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Night of the Yip-Hoot\u30fbSat, Dec. 30\u30fb9:30pm Doors\u30fb10:00pm Show"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!","url":"https://www.eventbrite.com/e/perreo-sf-nye-2024-roccapulco-sf-sfs-biggest-latin-reggaeton-nye-party-tickets-730266967157","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F636371299%2F183319970557%2F1%2Foriginal.20231106-220442?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C2160%2C1080\u0026s=1e004599de158a6555509d9eadd236fd","offers":{"url":"https://www.eventbrite.com/e/perreo-sf-nye-2024-roccapulco-sf-sfs-biggest-latin-reggaeton-nye-party-tickets-730266967157","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"San Francisco","addressRegion":"CA","streetAddress":"3140 Mission Street","postalCode":"94110","@type":"PostalAddress"},"geo":{"latitude":"37.7471428","@type":"GeoCoordinates","longitude":"-122.4191437"},"@type":"Place","name":"Roccapulco"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"SAN FRANCISCO'S BIGGEST LATIN - REGGAETON - HIPHOP NYE EVENT 2024! PERREO SF NYE 2024  @ ROCCAPULCO SF! Get Tickets before soldout!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"NYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink Tickets","url":"https://www.eventbrite.com/e/nye-2024-howl-at-the-moon-chicago-includes-premium-drink-tickets-tickets-721721036047","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F660401379%2F79037700981%2F1%2Foriginal.20231218-203050?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C0%2C720%2C360\u0026s=69a021a06d546145bf61098ec7d3d035","offers":{"url":"https://www.eventbrite.com/e/nye-2024-howl-at-the-moon-chicago-includes-premium-drink-tickets-tickets-721721036047","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Chicago","addressRegion":"IL","streetAddress":"26 W Hubbard St","postalCode":"60654","@type":"PostalAddress"},"geo":{"latitude":"41.890304","@type":"GeoCoordinates","longitude":"-87.629145"},"@type":"Place","name":"Howl at the Moon Chicago"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"New Year\u2019s Eve 2024 at Howl at the Moon Chicago!"}
#   </script>
#   <script type="application/ld+json">
#    {"startDate":"2023-12-31","endDate":"2024-01-01","name":"Hollywood Casino St Louis presents: NYE feat. Trixie Delight","url":"https://www.eventbrite.com/e/hollywood-casino-st-louis-presents-nye-feat-trixie-delight-tickets-732826552947","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F631432659%2F284734392749%2F1%2Foriginal.20231030-192025?h=200\u0026w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C88%2C726%2C363\u0026s=77d0c3ae7330c4f806277fec45ff2e5e","offers":{"url":"https://www.eventbrite.com/e/hollywood-casino-st-louis-presents-nye-feat-trixie-delight-tickets-732826552947","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"US","addressLocality":"Maryland Heights","addressRegion":"MO","streetAddress":"777 Casino Center Drive","postalCode":"63043","@type":"PostalAddress"},"geo":{"latitude":"38.7540402","@type":"GeoCoordinates","longitude":"-90.48160070000002"},"@type":"Place","name":"Hollywood Casino \u0026 Hotel St. Louis"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Ring in the New Year in the Hollywood Casino Nightclub with Trixie Delight."}
#   </script>
#  </body>
# </html>

# %%
events= soup.find_all('li',class_='search-main-content__events-list-item search-main-content__events-list-item__mobile')
for i in events:
    print(i.text)
# Out:
# Afterglow New Year • 2024Sun, Dec 31 •  10:00 PM Space 550Save this event: Afterglow New Year • 2024Share this event: Afterglow New Year • 2024Afterglow New Year • 2024Sun, Dec 31 •  10:00 PM Space 550Share this event: Afterglow New Year • 2024Save this event: Afterglow New Year • 2024
# Almost fullOFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉESun, Dec 31 •  9:00 PM Offshore RooftopSave this event: OFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉEShare this event: OFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉEAlmost fullOFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉESun, Dec 31 •  9:00 PM Offshore RooftopShare this event: OFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉESave this event: OFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉE
# Going fastNYE 2024 | All That Glitters at Mondrian South BeachSun, Dec 31 •  8:30 PM Mondrian South Beach MiamiSave this event: NYE 2024 | All That Glitters at Mondrian South BeachShare this event: NYE 2024 | All That Glitters at Mondrian South BeachGoing fastNYE 2024 | All That Glitters at Mondrian South BeachSun, Dec 31 •  8:30 PM Mondrian South Beach MiamiShare this event: NYE 2024 | All That Glitters at Mondrian South BeachSave this event: NYE 2024 | All That Glitters at Mondrian South Beach
# Going fastNew Years Eve Grand Salamander PartySun, Dec 31 •  9:00 PM Salamander Resort & SpaSave this event: New Years Eve Grand Salamander PartyShare this event: New Years Eve Grand Salamander PartyGoing fastNew Years Eve Grand Salamander PartySun, Dec 31 •  9:00 PM Salamander Resort & SpaShare this event: New Years Eve Grand Salamander PartySave this event: New Years Eve Grand Salamander Party
# NYE 2024: Doo-Wop All R&B Soul Music PartySun, Dec 31 •  7:00 PM The UrbanSave this event: NYE 2024: Doo-Wop All R&B Soul Music PartyShare this event: NYE 2024: Doo-Wop All R&B Soul Music PartyNYE 2024: Doo-Wop All R&B Soul Music PartySun, Dec 31 •  7:00 PM The UrbanShare this event: NYE 2024: Doo-Wop All R&B Soul Music PartySave this event: NYE 2024: Doo-Wop All R&B Soul Music Party
# Going fastNew Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night ClubSun, Dec 31 •  9:00 PM ROCBARSave this event: New Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night ClubShare this event: New Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night ClubGoing fastNew Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night ClubSun, Dec 31 •  9:00 PM ROCBARShare this event: New Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night ClubSave this event: New Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night Club
# Going fastNYE 2024 at Mission Navy YardSun, Dec 31 •  9:00 PM Mission - Navy YardSave this event: NYE 2024 at Mission Navy YardShare this event: NYE 2024 at Mission Navy YardGoing fastNYE 2024 at Mission Navy YardSun, Dec 31 •  9:00 PM Mission - Navy YardShare this event: NYE 2024 at Mission Navy YardSave this event: NYE 2024 at Mission Navy Yard
# Going fastNova New Year's Eve-#1 Party in Chicago For Recent Grads & Current StudentsSun, Dec 31 •  9:00 PM Nova NYESave this event: Nova New Year's Eve-#1 Party in Chicago For Recent Grads & Current StudentsShare this event: Nova New Year's Eve-#1 Party in Chicago For Recent Grads & Current StudentsGoing fastNova New Year's Eve-#1 Party in Chicago For Recent Grads & Current StudentsSun, Dec 31 •  9:00 PM Nova NYEShare this event: Nova New Year's Eve-#1 Party in Chicago For Recent Grads & Current StudentsSave this event: Nova New Year's Eve-#1 Party in Chicago For Recent Grads & Current Students
# Going fastSeattle New Years Eve Party 2024 | Gatsby's PenthouseSun, Dec 31 •  9:00 PM King Street Ballroom & PerchSave this event: Seattle New Years Eve Party 2024 | Gatsby's PenthouseShare this event: Seattle New Years Eve Party 2024 | Gatsby's PenthouseGoing fastSeattle New Years Eve Party 2024 | Gatsby's PenthouseSun, Dec 31 •  9:00 PM King Street Ballroom & PerchShare this event: Seattle New Years Eve Party 2024 | Gatsby's PenthouseSave this event: Seattle New Years Eve Party 2024 | Gatsby's Penthouse
# Going fast2024 Karat Magic: NYE PartySun, Dec 31 •  9:00 PM 601 S Harbour Island BlvdSave this event: 2024 Karat Magic: NYE PartyShare this event: 2024 Karat Magic: NYE PartyGoing fast2024 Karat Magic: NYE PartySun, Dec 31 •  9:00 PM 601 S Harbour Island BlvdShare this event: 2024 Karat Magic: NYE PartySave this event: 2024 Karat Magic: NYE Party
# Almost fullTOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+Sun, Dec 31 •  9:00 PM Bamboo atlantaSave this event: TOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+Share this event: TOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+Almost fullTOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+Sun, Dec 31 •  9:00 PM Bamboo atlantaShare this event: TOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+Save this event: TOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+
# Almost fullNew Year's Eve Party by Winter Park EventsSun, Dec 31 •  8:30 PM Winter Park Events CenterSave this event: New Year's Eve Party by Winter Park EventsShare this event: New Year's Eve Party by Winter Park EventsAlmost fullNew Year's Eve Party by Winter Park EventsSun, Dec 31 •  8:30 PM Winter Park Events CenterShare this event: New Year's Eve Party by Winter Park EventsSave this event: New Year's Eve Party by Winter Park Events
# Podfest Expo 2024Thu, Jan 25 •  9:00 AM Wyndham Orlando Resort International DriveSave this event: Podfest Expo 2024Share this event: Podfest Expo 2024Podfest Expo 2024Thu, Jan 25 •  9:00 AM Wyndham Orlando Resort International DriveShare this event: Podfest Expo 2024Save this event: Podfest Expo 2024
# Almost fullNYE 2024 Party at sections !Sun, Dec 31 •  9:00 PM Section, Seigle Avenue, Charlotte, NC, USASave this event: NYE 2024 Party at sections !Share this event: NYE 2024 Party at sections !Almost fullNYE 2024 Party at sections !Sun, Dec 31 •  9:00 PM Section, Seigle Avenue, Charlotte, NC, USAShare this event: NYE 2024 Party at sections !Save this event: NYE 2024 Party at sections !
# Almost fullHouston BBQ Throwdown 2024!Sun, Jan 14 •  1:00 PM Saint Arnold Brewing Company - Beer HallSave this event: Houston BBQ Throwdown 2024!Share this event: Houston BBQ Throwdown 2024!Almost fullHouston BBQ Throwdown 2024!Sun, Jan 14 •  1:00 PM Saint Arnold Brewing Company - Beer HallShare this event: Houston BBQ Throwdown 2024!Save this event: Houston BBQ Throwdown 2024!
# Going fastTHE GREATEST NYE ON EARTH 2024 | REVEL ATLANTASun, Dec 31 •  9:00 PM RevelSave this event: THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTAShare this event: THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTAGoing fastTHE GREATEST NYE ON EARTH 2024 | REVEL ATLANTASun, Dec 31 •  9:00 PM RevelShare this event: THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTASave this event: THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTA
# Almost fullNight of the Yip-HootSat, Dec 30 •  10:00 PM The Bell HouseSave this event: Night of the Yip-HootShare this event: Night of the Yip-HootAlmost fullNight of the Yip-HootSat, Dec 30 •  10:00 PM The Bell HouseShare this event: Night of the Yip-HootSave this event: Night of the Yip-Hoot
# PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!Sun, Dec 31 •  9:30 PM RoccapulcoSave this event: PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!Share this event: PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!Sun, Dec 31 •  9:30 PM RoccapulcoShare this event: PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!Save this event: PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!
# Almost fullNYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink TicketsSun, Dec 31 •  9:00 PM Howl at the Moon ChicagoSave this event: NYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink TicketsShare this event: NYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink TicketsAlmost fullNYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink TicketsSun, Dec 31 •  9:00 PM Howl at the Moon ChicagoShare this event: NYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink TicketsSave this event: NYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink Tickets
# Almost fullHollywood Casino St Louis presents: NYE feat. Trixie DelightSun, Dec 31 •  9:00 PM Hollywood Casino & Hotel St. LouisSave this event: Hollywood Casino St Louis presents: NYE feat. Trixie DelightShare this event: Hollywood Casino St Louis presents: NYE feat. Trixie DelightAlmost fullHollywood Casino St Louis presents: NYE feat. Trixie DelightSun, Dec 31 •  9:00 PM Hollywood Casino & Hotel St. LouisShare this event: Hollywood Casino St Louis presents: NYE feat. Trixie DelightSave this event: Hollywood Casino St Louis presents: NYE feat. Trixie Delight

# %%
name=[]
links=[]
for i in events:
    name.append(i.find('h2',class_="Typography_root__4bejd").text)
    links.append(i.find('a',class_="event-card-link")['href'])

# %%
name
# Out:
# ['Afterglow New Year • 2024',
#  "OFFSHORE ROOFTOP'S GLITZ & GLAM NEW YEAR'S EVE SOIRÉE",
#  'NYE 2024 | All That Glitters at Mondrian South Beach',
#  'New Years Eve Grand Salamander Party',
#  'NYE 2024: Doo-Wop All R&B Soul Music Party',
#  "New Year's Eve Party at ROCBAR - Chicago's Hottest 2-Story Night Club",
#  'NYE 2024 at Mission Navy Yard',
#  "Nova New Year's Eve-#1 Party in Chicago For Recent Grads & Current Students",
#  "Seattle New Years Eve Party 2024 | Gatsby's Penthouse",
#  '2024 Karat Magic: NYE Party',
#  'TOAST NYE | Sunday December 31 2023 | at Bamboo Atlanta | 21+',
#  "New Year's Eve Party by Winter Park Events",
#  'Podfest Expo 2024',
#  'NYE 2024 Party at sections !',
#  'Houston BBQ Throwdown 2024!',
#  'THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTA',
#  'Night of the Yip-Hoot',
#  'PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Biggest Latin Reggaeton NYE Party!',
#  'NYE 2024 | Howl at the Moon, Chicago | Includes Premium Drink Tickets',
#  'Hollywood Casino St Louis presents: NYE feat. Trixie Delight']

# %%
links
# Out:
# ['https://www.eventbrite.com/e/afterglow-new-year-2024-tickets-757622428077?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/offshore-rooftops-glitz-glam-new-years-eve-soiree-tickets-738105522487?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/nye-2024-all-that-glitters-at-mondrian-south-beach-tickets-742728820897?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/new-years-eve-grand-salamander-party-tickets-745638283177?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/nye-2024-doo-wop-all-rb-soul-music-party-tickets-777737342327?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/new-years-eve-party-at-rocbar-chicagos-hottest-2-story-night-club-tickets-738190115507?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/nye-2024-at-mission-navy-yard-tickets-760126718477?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/nova-new-years-eve-1-party-in-chicago-for-recent-grads-current-students-tickets-707155640557?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/seattle-new-years-eve-party-2024-gatsbys-penthouse-tickets-648360903917?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/2024-karat-magic-nye-party-tickets-764161285977?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/toast-nye-sunday-december-31-2023-at-bamboo-atlanta-21-tickets-770998636677?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/new-years-eve-party-by-winter-park-events-tickets-722077572457?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/podfest-expo-2024-tickets-638791581817?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/nye-2024-party-at-sections-tickets-738868404287?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/houston-bbq-throwdown-2024-tickets-729650061977?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/the-greatest-nye-on-earth-2024-revel-atlanta-tickets-755598053117?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/night-of-the-yip-hoot-tickets-778922818117?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/perreo-sf-nye-2024-roccapulco-sf-sfs-biggest-latin-reggaeton-nye-party-tickets-730266967157?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/nye-2024-howl-at-the-moon-chicago-includes-premium-drink-tickets-tickets-721721036047?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/hollywood-casino-st-louis-presents-nye-feat-trixie-delight-tickets-732826552947?aff=ebdssbdestsearch']

# %%
date_time=[]
location=[]
price=[]
about=[]
for link in links:
    event_url=requests.get(link).text
    so=BeautifulSoup(event_url,'lxml')
    event=so.find_all('div',class_='eds-structure__body')
    for j in  event:
        date_time.append(j.find('span',class_="date-info__full-datetime").text)
        about.append(j.find('div',class_="has-user-generated-content").text)
        try:
            price.append(j.find('div',class_="conversion-bar__panel-info").text)
        except:
            price.append(np.nan)
        try:
            location.append(j.find('p',class_="location-info__address-text").text)
        except:
            location.append(np.nan)
    
    
df =pd.DataFrame({'Name':name,'Price':price,'Date_time':date_time,"Location":location,"About":about})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_132597/2968833145.py in <module>
#      20
#      21
# ---> 22 df =pd.DataFrame({'Name':name,'Price':price,'Date_time':date_time,"Location":location,"About":about})
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     479             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     480
# --> 481     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     482
#     483
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     113         # figure out the index, if necessary
#     114         if index is None:
# --> 115             index = _extract_index(arrays)
#     116         else:
#     117             index = ensure_index(index)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     653         lengths = list(set(raw_lengths))
#     654         if len(lengths) > 1:
# --> 655             raise ValueError("All arrays must be of the same length")
#     656
#     657         if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
df

# %%
final
# Out:
#                                                  Name  Price Date_time  \
# 0   [NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA]  [nan]     [nan]
# 1                    [CLIMAX FRIDAYS | REVEL ATLANTA]  [nan]     [nan]
# 2         [THE GREATEST SHOW ON EARTH| REVEL ATLANTA]  [nan]     [nan]
# 3              [TRAP VS R&B MLK WEEKEND  | ELLEVEN45]  [nan]     [nan]
# 4           [ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE]  [nan]     [nan]
# ..                                                ...    ...       ...
# 75                            [Night of the Yip-Hoot]  [nan]     [nan]
# 76  [PERREO SF NYE 2024! @ ROCCAPULCO SF! SFs Bigg...  [nan]     [nan]
# 77  [NYE 2024 | Howl at the Moon, Chicago | Includ...  [nan]     [nan]
# 78  [The Last Day Party of 2023  #Antioch  Sky Bar...  [nan]     [nan]
# 79  [Hollywood Casino St Louis presents: NYE feat....  [nan]     [nan]
#
#    Location  About
# 0     [nan]  [nan]
# 1     [nan]  [nan]
# 2     [nan]  [nan]
# 3     [nan]  [nan]
# 4     [nan]  [nan]
# ..      ...    ...
# 75    [nan]  [nan]
# 76    [nan]  [nan]
# 77    [nan]  [nan]
# 78    [nan]  [nan]
# 79    [nan]  [nan]
#
# [80 rows x 5 columns]

# %%
name

# %%
for a in range(1,5):
    webpage=requests.get("https://www.eventbrite.com/d/united-states/all-events/?page={}".format(a)).text
    soup = BeautifulSoup(webpage,'lxml')
    events= soup.find_all('li',class_='search-main-content__events-list-item search-main-content__events-list-item__mobile')
    name=[]
    link=[]
    for i in events:
        name.append(i.find('h2',class_="Typography_root__4bejd").text)
        links.append(i.find('a',class_="event-card-link")['href'])

# %%
name
# Out:
# []

# %%
data_list = []

for a in range(1, 501):
    webpage = requests.get("https://www.eventbrite.com/d/united-states/all-events/?page={}".format(a)).text
    soup = BeautifulSoup(webpage, 'lxml')
    events = soup.find_all('li', class_='search-main-content__events-list-item')
    
    for event in events:
        name = event.find('h2', class_="Typography_root__4bejd").text
        link = event.find('a', class_="event-card-link")['href']
        
        event_url = requests.get(link).text
        so = BeautifulSoup(event_url, 'lxml')
        event_info = so.find('div', class_='eds-structure__body')
        
        try:
            about = event_info.find('div', class_="has-user-generated-content").text
        except AttributeError:
            about = np.nan
               
        try:
            date_time = event_info.find('span', class_="date-info__full-datetime").text
        except AttributeError:
            date_time = np.nan
        
        try:
            price = event_info.find('div', class_="conversion-bar__panel-info").text
        except AttributeError:
            price = np.nan
        
        try:
            location = event_info.find('p', class_="location-info__address-text").text
        except AttributeError:
            location = np.nan
        
        # Append data as dictionaries to the list
        data_list.append({'Name': name, 'Price': price, 'Date_time': date_time, 'Location': location, 'About': about})

# Create a DataFrame from the list of dictionaries
final = pd.DataFrame(data_list)

# %%
final
# Out:
#                                                   Name        Price  \
# 0      NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA  From $32.64
# 1              ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE         Free
# 2             THE GREATEST SHOW ON EARTH REVEL ATLANTA          NaN
# 3    THE GREATEST NYE ON EARTH NEW YEARS EVE | REVE...    $0 – $100
# 4              HANGOVER ROOFTOP BRUNCH AT SUITE LOUNGE          NaN
# ..                                                 ...          ...
# 115             New Years Eve 2024 - The Roaring 20's!          NaN
# 116               Old Crow Wrigleyville New Year's Eve          NaN
# 117  DEUCES 23 : New Years Eve Celebration [AFROBEA...          NaN
# 118                                   Pink Goes Purple          NaN
# 119            New Years Eve Party 2024 - Hilton Miami          NaN
#
#                                          Date_time           Location  \
# 0    December 31 · 9pm - January 1, 2024 · 4am EST              Katra
# 1              Saturday, December 30 · 3 - 9pm EST  Suite Food Lounge
# 2       December 23 · 10pm - December 24 · 3am EST      REVEL ATLANTA
# 3        Ends on Monday, January 1, 2024 · 3am EST              Revel
# 4            Monday, January 1, 2024 · 3 - 9pm EST  Suite Food Lounge
# ..                                             ...                ...
# 115                                            NaN                NaN
# 116                                            NaN                NaN
# 117                                            NaN                NaN
# 118                                            NaN                NaN
# 119                                            NaN                NaN
#
#                                                  About
# 0    5 HOURS OF PREMIUM OPEN BARCHAMPAGNE TOAST AT ...
# 1    Celebrity guest, live music by Atlanta's top D...
# 2    Join us every week at THE GREATEST SHOW ON EAR...
# 3    THE GREATEST NEW YEAR'S EVE ON EARTH 2024 | RE...
# 4    Welcome to the Hangover Rooftop Brunch at Suit...
# ..                                                 ...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
#
# [120 rows x 5 columns]

# %%
final.sample(5)
# Out:
#                                                  Name         Price  \
# 67     THE GREATEST NYE ON EARTH 2024 | REVEL ATLANTA     $0 – $100
# 28  Mersiv - Jannus Live - New Years Weekend Celeb...     $25 – $45
# 44  Gatsby's Prohibition New Years Eve  Party 2024...  $89 – $1,000
# 12                     Windows on the River NYE Party   $195 – $230
# 93                             Braggn Blonde- Georgia           NaN
#
#                                             Date_time              Location  \
# 67      December 31 · 9pm - January 1, 2024 · 3am EST                 Revel
# 28  December 30 · 7pm - December 31 · 12am EST. Do...           Jannus Live
# 44   December 31 · 9pm - January 1, 2024 · 1:30am CST            Morgan MFG
# 12      December 31 · 8pm - January 1, 2024 · 1am EST  Windows on the River
# 93                                                NaN                   NaN
#
#                                                 About
# 67  THE GREATEST NEW YEAR'S EVE ON EARTH 2024 | RE...
# 28  ALLIANCE presents:MERSIVhttps://soundcloud.com...
# 44  Ring in 2024 at Gatsby's Prohibition New Year'...
# 12  Ring in 2024 at Windows On The River. The hott...
# 93                                                NaN

# %%
final.to_csv("event_data.csv")

# %%
final[85:120].to_csv("event.csv")

# %%
df = final[["Name","Price","Date_time","Location"]]

# %%
df
# Out:
#                                                   Name        Price  \
# 0      NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA  From $32.64
# 1              ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE         Free
# 2             THE GREATEST SHOW ON EARTH REVEL ATLANTA          NaN
# 3    THE GREATEST NYE ON EARTH NEW YEARS EVE | REVE...    $0 – $100
# 4              HANGOVER ROOFTOP BRUNCH AT SUITE LOUNGE          NaN
# ..                                                 ...          ...
# 115             New Years Eve 2024 - The Roaring 20's!          NaN
# 116               Old Crow Wrigleyville New Year's Eve          NaN
# 117  DEUCES 23 : New Years Eve Celebration [AFROBEA...          NaN
# 118                                   Pink Goes Purple          NaN
# 119            New Years Eve Party 2024 - Hilton Miami          NaN
#
#                                          Date_time           Location
# 0    December 31 · 9pm - January 1, 2024 · 4am EST              Katra
# 1              Saturday, December 30 · 3 - 9pm EST  Suite Food Lounge
# 2       December 23 · 10pm - December 24 · 3am EST      REVEL ATLANTA
# 3        Ends on Monday, January 1, 2024 · 3am EST              Revel
# 4            Monday, January 1, 2024 · 3 - 9pm EST  Suite Food Lounge
# ..                                             ...                ...
# 115                                            NaN                NaN
# 116                                            NaN                NaN
# 117                                            NaN                NaN
# 118                                            NaN                NaN
# 119                                            NaN                NaN
#
# [120 rows x 4 columns]

# %%
df.to_csv("events.csv")

# %%
data=df[1:21]

# %%
data.to_csv("event_dataset")
