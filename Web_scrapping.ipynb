# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
webpage=requests.get("https://www.eventbrite.com/d/united-states/all-events/?page=1").text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    United States All Events | Eventbrite
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="en" http-equiv="Content-Language"/>
#   <link rel="preconnect" src="https://cdn.evbstatic.com"/>
#   <link rel="dns-prefetch" src="https://cdn.evbstatic.com"/>
#   <link rel="preconnect" src="https://img.evbuc.com"/>
#   <link rel="dns-prefetch" src="https://img.evbuc.com"/>
#   <link rel="preconnect" src="https://cdn.transcend.io"/>
#   <link rel="dns-prefetch" src="https://cdn.transcend.io"/>
#   <link rel="preconnect" src="https://cdn.branch.io"/>
#   <link rel="dns-prefetch" src="https://cdn.branch.io"/>
#   <link rel="preconnect" src="https://www.googletagmanager.com"/>
#   <link rel="dns-prefetch" src="https://www.googletagmanager.com"/>
# ...

# %%
events= soup.find_all('li',class_='search-main-content__events-list-item search-main-content__events-list-item__mobile')
for i in events:
    print(i.text)
# Out:
# Almost fullNEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRASun, Dec 31 •  9:00 PM KatraSave this event: NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRAShare this event: NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRAAlmost fullNEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRASun, Dec 31 •  9:00 PM KatraShare this event: NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRASave this event: NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA
# Going fastROOFTOP WATCH PARTY | SUITE FOOD LOUNGESat, Dec 30 •  3:00 PM Suite Food LoungeSave this event: ROOFTOP WATCH PARTY | SUITE FOOD LOUNGEShare this event: ROOFTOP WATCH PARTY | SUITE FOOD LOUNGEGoing fastROOFTOP WATCH PARTY | SUITE FOOD LOUNGESat, Dec 30 •  3:00 PM Suite Food LoungeShare this event: ROOFTOP WATCH PARTY | SUITE FOOD LOUNGESave this event: ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE
# ...

# %%
name=[]
links=[]
for i in events:
    name.append(i.find('h2',class_="Typography_root__4bejd").text)
    links.append(i.find('a',class_="event-card-link")['href'])

# %%
name
# Out:
# ['NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA',
#  'ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE',
#  'HANGOVER ROOFTOP BRUNCH AT SUITE LOUNGE',
#  'THE GREATEST SHOW ON EARTH| REVEL ATLANTA',
#  'CLIMAX FRIDAYS | REVEL ATLANTA',
#  'THE GREATEST SHOW ON EARTH REVEL ATLANTA',
#  'TRAP VS R&B MLK WEEKEND  | ELLEVEN45',
#  '12TH ANNUAL NEW YEARS EVE CASINO NIGHT',
#  'Winter Skies 12/21/23',
#  'Jim Irsay Collection Exhibit & Concert, Los Angeles - January 11, 2024',
#  "It's A New Day + Breakfast Of Champions Block Party 2024",
#  "Tampa New Year's Eve Party Countdown - NYElectric® 2024",
#  'Quality Control / Sincerely From the Six/ Luving Da Crew  NYE Celebration',
#  '2024 Reno Latin Dance Fest',
#  "2024 Black Tie New Year's Eve Gala at the Luxurious Willard",
#  'New Years Eve Atlanta 2024',
#  'THE GREATEST NYE ON EARTH NEW YEARS EVE | REVEL ATLANTA',
#  "Chicago New Year's Eve Bar Crawl in Wrigleyville",
#  "New Year's Eve Party 2024 at Hilton Chicago with Kiss FM",
# ...

# %%
links
# Out:
# ['https://www.eventbrite.com/e/new-years-eve-5-hours-premium-open-bar-at-katra-tickets-487856691497?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/rooftop-watch-party-suite-food-lounge-tickets-130323899291?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/hangover-rooftop-brunch-at-suite-lounge-tickets-127257012149?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/the-greatest-show-on-earth-revel-atlanta-tickets-143005871411?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/climax-fridays-revel-atlanta-tickets-115577717063?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/the-greatest-show-on-earth-revel-atlanta-tickets-179620629137?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/trap-vs-rb-mlk-weekend-elleven45-tickets-169221438879?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/12th-annual-new-years-eve-casino-night-tickets-673514910227?aff=ebdssbdestsearch',
# ...

# %%
date_time=[]
location=[]
price=[]
about=[]
for link in links:
    event_url=requests.get(link).text
    so=BeautifulSoup(event_url,'lxml')
    event=so.find_all('div',class_='eds-structure__body')
    for j in  event:
        date_time.append(j.find('span',class_="date-info__full-datetime").text)
        about.append(j.find('div',class_="has-user-generated-content").text)
        try:
            price.append(j.find('div',class_="conversion-bar__panel-info").text)
        except:
            price.append(np.nan)
        try:
            location.append(j.find('p',class_="location-info__address-text").text)
        except:
            location.append(np.nan)
    
    
df =pd.DataFrame({'Name':name,'Price':price,'Date_time':date_time,"Location":location,"About":about})

# %%
df
# Out:
#                                                  Name          Price  \
# 0     NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA    From $32.64
# 1             ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE           Free
# 2             HANGOVER ROOFTOP BRUNCH AT SUITE LOUNGE            NaN
# 3           THE GREATEST SHOW ON EARTH| REVEL ATLANTA            NaN
# 4                      CLIMAX FRIDAYS | REVEL ATLANTA            NaN
# 5            THE GREATEST SHOW ON EARTH REVEL ATLANTA            NaN
# 6                TRAP VS R&B MLK WEEKEND  | ELLEVEN45            NaN
# 7              12TH ANNUAL NEW YEARS EVE CASINO NIGHT     $60 – $400
# 8                               Winter Skies 12/21/23            $70
# 9   Jim Irsay Collection Exhibit & Concert, Los An...           Free
# 10  It's A New Day + Breakfast Of Champions Block ...   $30 – $4,800
# 11  Tampa New Year's Eve Party Countdown - NYElect...  $169 – $1,049
# 12  Quality Control / Sincerely From the Six/ Luvi...       $0 – $25
# ...

# %%
df=[] 
for a in range(1,5):
    webpage=requests.get("https://www.eventbrite.com/d/united-states/all-events/?page={}".format(a)).text
    soup = BeautifulSoup(webpage,'lxml')
    events= soup.find_all('li',class_='search-main-content__events-list-item search-main-content__events-list-item__mobile')
    name=[]
    links=[]
    date_time=[]
    location=[]
    price=[]
    about=[]
    for i in events:
        name.append(i.find('h2',class_="Typography_root__4bejd").text)
        links.append(i.find('a',class_="event-card-link")['href'])
        event_url=requests.get(link).text
        so=BeautifulSoup(event_url,'lxml')            
        event=so.find_all('div',class_='eds-structure__body')
            
        try:
            date_time.append(event.find('span',class_="date-info__full-datetime").text)
        except:
            date_time.append(np.nan)
                
        try:
            about.append(event.find('div',class_="has-user-generated-content").text)
        except:
            about.append(np.nan)
                
        try:
            price.append(event.find('div',class_="conversion-bar__panel-info").text)
        except:
            price.append(np.nan)
            
        try:
            location.append(event.find('p',class_="location-info__address-text").text)
        except:
            location.append(np.nan)
    
    
        df.append({'Name':name,'Price':price,'Date_time':date_time,"Location":location,"About":about})
        
final=pd.DataFrame(df)

# %%
final
# Out:
#                                                  Name        Price  \
# 0     NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA  From $32.64
# 1             ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE         Free
# 2             HANGOVER ROOFTOP BRUNCH AT SUITE LOUNGE          NaN
# 3           THE GREATEST SHOW ON EARTH| REVEL ATLANTA          NaN
# 4                      CLIMAX FRIDAYS | REVEL ATLANTA          NaN
# 5            THE GREATEST SHOW ON EARTH REVEL ATLANTA          NaN
# 6                TRAP VS R&B MLK WEEKEND  | ELLEVEN45          NaN
# 7              12TH ANNUAL NEW YEARS EVE CASINO NIGHT   $60 – $400
# 8                               Winter Skies 12/21/23          $70
# 9   Jim Irsay Collection Exhibit & Concert, Los An...         Free
# 10  It's A New Day + Breakfast Of Champions Block ...          NaN
# 11  Tampa New Year's Eve Party Countdown - NYElect...          NaN
# 12  Quality Control / Sincerely From the Six/ Luvi...          NaN
# ...

# %%
name
# Out:
# []

# %%
for a in range(1,5):
    webpage=requests.get("https://www.eventbrite.com/d/united-states/all-events/?page={}".format(a)).text
    soup = BeautifulSoup(webpage,'lxml')
    events= soup.find_all('li',class_='search-main-content__events-list-item search-main-content__events-list-item__mobile')
    name=[]
    link=[]
    for i in events:
        name.append(i.find('h2',class_="Typography_root__4bejd").text)
        links.append(i.find('a',class_="event-card-link")['href'])

# %%
name

# %%
data_list = []

for a in range(1, 5):
    webpage = requests.get("https://www.eventbrite.com/d/united-states/all-events/?page={}".format(a)).text
    soup = BeautifulSoup(webpage, 'lxml')
    events = soup.find_all('li', class_='search-main-content__events-list-item search-main-content__events-list-item__mobile')
    
    for event in events:
        name = event.find('h2', class_="Typography_root__4bejd").text
        link = event.find('a', class_="event-card-link")['href']
        
        event_url = requests.get(link).text
        so = BeautifulSoup(event_url, 'lxml')
        event_info = so.find('div', class_='eds-structure__body')
        
        try:
            about = event_info.find('div', class_="has-user-generated-content").text
        except AttributeError:
            about = np.nan
               
        try:
            date_time = event_info.find('span', class_="date-info__full-datetime").text
        except AttributeError:
            date_time = np.nan
        
        try:
            price = event_info.find('div', class_="conversion-bar__panel-info").text
        except AttributeError:
            price = np.nan
        
        try:
            location = event_info.find('p', class_="location-info__address-text").text
        except AttributeError:
            location = np.nan
        
        # Append data as dictionaries to the list
        data_list.append({'Name': name, 'Price': price, 'Date_time': date_time, 'Location': location, 'About': about})

# Create a DataFrame from the list of dictionaries
final = pd.DataFrame(data_list)

# %%
final
# Out:
#                                                  Name        Price  \
# 0     NEW YEARS EVE 5 HOURS PREMIUM OPEN BAR AT KATRA  From $32.64
# 1             ROOFTOP WATCH PARTY | SUITE FOOD LOUNGE         Free
# 2             HANGOVER ROOFTOP BRUNCH AT SUITE LOUNGE          NaN
# 3           THE GREATEST SHOW ON EARTH| REVEL ATLANTA          NaN
# 4                      CLIMAX FRIDAYS | REVEL ATLANTA          NaN
# 5            THE GREATEST SHOW ON EARTH REVEL ATLANTA          NaN
# 6                TRAP VS R&B MLK WEEKEND  | ELLEVEN45          NaN
# 7              12TH ANNUAL NEW YEARS EVE CASINO NIGHT   $60 – $400
# 8                               Winter Skies 12/21/23          $70
# 9   Jim Irsay Collection Exhibit & Concert, Los An...         Free
# 10  It's A New Day + Breakfast Of Champions Block ...          NaN
# 11  Tampa New Year's Eve Party Countdown - NYElect...          NaN
# 12  Quality Control / Sincerely From the Six/ Luvi...          NaN
# ...
